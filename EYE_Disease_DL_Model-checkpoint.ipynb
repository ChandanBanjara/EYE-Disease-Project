# %%
# connect to google deriew

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir -p ~/ .kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d gunavenkatdoddi/eye-diseases-classification

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Eye Disease Prediction Dataset/eye-diseases-classification.zip','r')
zip_ref.extractall('/content/drive/MyDrive/Eye Disease Prediction Dataset/')
zip_ref.close()

# %% [markdown]
# # Split Dataset like this :-
# #     traindataset/
# #     folder1/
# #     folder2/
# #     folder3/
# #     folder4/
#
# #     testdataset/
# #         folder1/
# #         folder2/
# #         folder3/
# #         folder4/

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
import random

# %%
data_dir = "/content/drive/MyDrive/Eye Disease Prediction Dataset/dataset"  # diectory Where original data is stored
train_dir = "/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/traindataset"  # directorye Where  you want to store train data
test_dir = "/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset"    # directorye Where  you want to store test data

# Split ratio (e.g., 80% train, 20% test)
split_ratio = 0.8

# %%
def split_data(data_dir, train_dir, test_dir, split_ratio):
    folders = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]  # Adjust based on your folder names

    for folder in folders:
        folder_path = os.path.join(data_dir, folder)
        images = os.listdir(folder_path)

        # Shuffle the images before splitting
        random.shuffle(images)

        # Split images into train and test
        train_images, test_images = train_test_split(images, test_size=(1-split_ratio))

        # Create train and test directories for each class
        os.makedirs(os.path.join(train_dir, folder), exist_ok=True)
        os.makedirs(os.path.join(test_dir, folder), exist_ok=True)

        # Move train images
        for image in train_images:
            shutil.copy(os.path.join(folder_path, image), os.path.join(train_dir, folder, image))

        # Move test images
        for image in test_images:
            shutil.copy(os.path.join(folder_path, image), os.path.join(test_dir, folder, image))

    print("Data successfully split into train and test sets!")

# %%
split_data(data_dir, train_dir, test_dir, split_ratio)
# Out:
# Data successfully split into train and test sets!

# %% [markdown]
# # Remove Incurrepted Images from traindataset and testdataset folder .

# %%
from PIL import Image
import os

def check_images(data_dir):
    folders = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]
    for folder in folders:
        folder_path = os.path.join(data_dir, folder)
        for image_file in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_file)
            try:
                img = Image.open(image_path)
                img.verify()  # Check if the image is valid
            except (IOError, SyntaxError) as e:
                print(f"Removing corrupted file: {image_path}")
                os.remove(image_path)

check_images("/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/traindataset")

# %%
from PIL import Image
import os

def check_images(data_dir):
    folders = ["cataract", "diabetic_retinopathy", "glaucoma", "normal"]
    for folder in folders:
        folder_path = os.path.join(data_dir, folder)
        for image_file in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_file)
            try:
                img = Image.open(image_path)
                img.verify()  # Check if the image is valid
            except (IOError, SyntaxError) as e:
                print(f"Removing corrupted file: {image_path}")
                os.remove(image_path)

check_images("/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset")

# %% [markdown]
#  # model making

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout

# %%
# genrators

train_ds  = keras.utils.image_dataset_from_directory(
    directory='/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/traindataset',
    labels='inferred',
    label_mode ='int',
    batch_size=32,
    image_size = (256,256)
)



validation_ds  = keras.utils.image_dataset_from_directory(
    directory='/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset',
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size = (256,256)
)
# Out:
# Found 4059 files belonging to 4 classes.
# Found 1532 files belonging to 4 classes.

# %%
# Normalization

def process(image,label):
    image = tf.cast(image/255. , tf.float32)
    return image,label


train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32, kernel_size=(3,3), padding='valid', activation='relu', input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2, padding='valid'))


model.add(Conv2D(64, kernel_size=(3,3), padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2, padding='valid'))


model.add(Conv2D(128, kernel_size=(3,3), padding='valid', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2, padding='valid'))


model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# ...
# Total params: 14847492 (56.64 MB)
# Trainable params: 14847492 (56.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=15, validation_data=validation_ds)
# Out:
# Epoch 1/15
#  44/127 [=========>....................] - ETA: 48s - loss: 1.3421 - accuracy: 0.4993
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2d48f316a1f6> in <cell line: 1>()
# ----> 1 history = model.fit(train_ds,epochs=15, validation_data=validation_ds)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
model.save('/content/drive/MyDrive/Eye Disease Prediction Dataset/Eye_Disease_DL_Model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], color='red', label='train')
plt.plot(history.history['val_accuracy'], color='blue', label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], color='red', label='train')
plt.plot(history.history['val_loss'], color='blue', label='validation')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/Eye Disease Prediction Dataset/Eye_Disease_DL_Model.h5')

# %%
import cv2
import matplotlib.pyplot as plt
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/cataract/0_left.jpg')
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (512, 512, 3)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 127ms/step
# array([[0., 0., 1., 0.]], dtype=float32)

# %%
import cv2
import matplotlib.pyplot as plt
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/cataract/1084_right.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[1., 0., 0., 0.]], dtype=float32)

# %%
import cv2
import matplotlib.pyplot as plt
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/cataract/1102_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[1., 0., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/diabetic_retinopathy/10003_left.jpeg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/diabetic_retinopathy/10009_right.jpeg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/diabetic_retinopathy/1000_left.jpeg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/diabetic_retinopathy/10013_right.jpeg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/glaucoma/1020_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/glaucoma/1210_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/glaucoma/1215_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0., 0., 1., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/glaucoma/1222_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/normal/1060_right.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[0., 0., 1., 0.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/normal/2332_right.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([[0., 0., 0., 1.]], dtype=float32)

# %%
test_img = cv2.imread('/content/drive/MyDrive/Eye Disease Prediction Dataset/SplitDataset/testdataset/normal/2351_left.jpg')
plt.imshow(test_img)

# %%
test_img = cv2.resize(test_img,(256,256))
test_input = test_img.reshape((1,256,256,3))
model.predict(test_input)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[0., 1., 0., 0.]], dtype=float32)
